// %%
import "dotenv/config";
import { CheerioWebBaseLoader } from "@langchain/community/document_loaders/web/cheerio";
import { RecursiveCharacterTextSplitter } from "@langchain/textsplitters";
import { MemoryVectorStore } from "langchain/vectorstores/memory";
import { BedrockEmbeddings } from "@langchain/aws";

const urls = [
  "https://lilianweng.github.io/posts/2023-06-23-agent/",
  "https://lilianweng.github.io/posts/2023-03-15-prompt-engineering/",
  "https://lilianweng.github.io/posts/2023-10-25-adv-attack-llm/",
];

const docs = await Promise.all(
  urls.map((url) => new CheerioWebBaseLoader(url).load())
);
const docsList = docs.flat();

const textSplitter = new RecursiveCharacterTextSplitter({
  chunkSize: 250,
  chunkOverlap: 0,
});
const docSplits = await textSplitter.splitDocuments(docsList);


console.log(docSplits);
// Out:
// [
//   Document {
//     pageContent: 'if (localStorage.getItem("pref-theme") === "dark") {\n' +
//       "        document.body.classList.add('dark');\n" +
//       '    } else if (localStorage.getItem("pref-theme") === "light") {\n' +
//       "        document.body.classList.remove('dark')",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 3, to: 6 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "} else if (window.matchMedia('(prefers-color-scheme: dark)').matches) {\n" +
//       "        document.body.classList.add('dark');\n" +
//       "    }",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 7, to: 9 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "MathJax = {\n" +
//       "    tex: {\n" +
//       "      inlineMath: [['$', '$'], ['\\\\(', '\\\\)']],\n" +
//       "      displayMath: [['$$','$$'], ['\\\\[', '\\\\]']],\n" +
//       "      processEscapes: true,\n" +
//       "      processEnvironments: true\n" +
//       "    },\n" +
//       "    options: {",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 14, to: 21 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "skipHtmlTags: ['script', 'noscript', 'style', 'textarea', 'pre']\n" +
//       "    }\n" +
//       "  };",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 22, to: 24 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "window.addEventListener('load', (event) => {\n" +
//       '      document.querySelectorAll("mjx-container").forEach(function(x){\n' +
//       "        x.parentElement.classList += 'has-jax'})\n" +
//       "    });",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 26, to: 29 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Lil'Log",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 39, to: 39 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "|",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 57, to: 57 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Posts\n" +
//       "                \n" +
//       "            \n" +
//       "            \n" +
//       "                \n" +
//       "                    Archive\n" +
//       "                \n" +
//       "            \n" +
//       "            \n" +
//       "                \n" +
//       "                    Search",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 64, to: 74 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Tags\n" +
//       "                \n" +
//       "            \n" +
//       "            \n" +
//       "                \n" +
//       "                    FAQ",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 79, to: 84 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "LLM Powered Autonomous Agents\n" +
//       "    \n" +
//       "    Date: June 23, 2023  |  Estimated Reading Time: 31 min  |  Author: Lilian Weng\n" +
//       "\n" +
//       "\n" +
//       "   \n" +
//       "    \n" +
//       "        \n" +
//       "            Table of Contents",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 96, to: 104 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Agent System Overview\n" +
//       "                \n" +
//       "                    Component One: Planning\n" +
//       "                        \n" +
//       "                \n" +
//       "                    Task Decomposition",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 109, to: 114 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Self-Reflection\n" +
//       "                \n" +
//       "                \n" +
//       "                    Component Two: Memory\n" +
//       "                        \n" +
//       "                \n" +
//       "                    Types of Memory",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 116, to: 122 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Maximum Inner Product Search (MIPS)\n" +
//       "                \n" +
//       "                \n" +
//       "                    Component Three: Tool Use\n" +
//       "                \n" +
//       "                    Case Studies",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 124, to: 129 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Scientific Discovery Agent\n" +
//       "                \n" +
//       "                    Generative Agents Simulation\n" +
//       "                \n" +
//       "                    Proof-of-Concept Examples\n" +
//       "                \n" +
//       "                \n" +
//       "                    Challenges",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 132, to: 139 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Citation\n                \n                    References",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 141, to: 143 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Building agents with LLM (large language model) as its core controller is a cool concept. Several proof-of-concepts demos, such as AutoGPT, GPT-Engineer and BabyAGI, serve as inspiring examples. The potentiality of LLM extends beyond generating",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 150, to: 150 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "well-written copies, stories, essays and programs; it can be framed as a powerful general problem solver.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 150, to: 150 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Agent System Overview#\n" +
//       "In a LLM-powered autonomous agent system, LLM functions as the agent’s brain, complemented by several key components:",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 151, to: 152 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Planning",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 154, to: 154 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Subgoal and decomposition: The agent breaks down large tasks into smaller, manageable subgoals, enabling efficient handling of complex tasks.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 156, to: 156 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Reflection and refinement: The agent can do self-criticism and self-reflection over past actions, learn from mistakes and refine them for future steps, thereby improving the quality of final results.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 157, to: 157 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Memory",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 160, to: 160 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Short-term memory: I would consider all the in-context learning (See Prompt Engineering) as utilizing short-term memory of the model to learn.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 162, to: 162 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Long-term memory: This provides the agent with the capability to retain and recall (infinite) information over extended periods, often by leveraging an external vector store and fast retrieval.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 163, to: 163 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Tool use",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 166, to: 166 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "The agent learns to call external APIs for extra information that is missing from the model weights (often hard to change after pre-training), including current information, code execution capability, access to proprietary information sources and",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 168, to: 168 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "more.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 168, to: 168 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Overview of a LLM-powered autonomous agent system.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 174, to: 174 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Component One: Planning#\n" +
//       "A complicated task usually involves many steps. An agent needs to know what they are and plan ahead.\n" +
//       "Task Decomposition#",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 176, to: 178 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Chain of thought (CoT; Wei et al. 2022) has become a standard prompting technique for enhancing model performance on complex tasks. The model is instructed to “think step by step” to utilize more test-time computation to decompose hard tasks into",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 179, to: 179 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "smaller and simpler steps. CoT transforms big tasks into multiple manageable tasks and shed lights into an interpretation of the model’s thinking process.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 179, to: 179 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Tree of Thoughts (Yao et al. 2023) extends CoT by exploring multiple reasoning possibilities at each step. It first decomposes the problem into multiple thought steps and generates multiple thoughts per step, creating a tree structure. The search",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 180, to: 180 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "process can be BFS (breadth-first search) or DFS (depth-first search) with each state evaluated by a classifier (via a prompt) or majority vote.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 180, to: 180 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: 'Task decomposition can be done (1) by LLM with simple prompting like "Steps for XYZ.\\n1.", "What are the subgoals for achieving XYZ?", (2) by using task-specific instructions; e.g. "Write a story outline." for writing a novel, or (3) with human',
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 181, to: 181 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "inputs.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 181, to: 181 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Another quite distinct approach, LLM+P (Liu et al. 2023), involves relying on an external classical planner to do long-horizon planning. This approach utilizes the Planning Domain Definition Language (PDDL) as an intermediate interface to describe",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 182, to: 182 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "the planning problem. In this process, LLM (1) translates the problem into “Problem PDDL”, then (2) requests a classical planner to generate a PDDL plan based on an existing “Domain PDDL”, and finally (3) translates the PDDL plan back into natural",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 182, to: 182 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "language. Essentially, the planning step is outsourced to an external tool, assuming the availability of domain-specific PDDL and a suitable planner which is common in certain robotic setups but not in many other domains.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 182, to: 182 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Self-Reflection#",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 183, to: 183 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Self-reflection is a vital aspect that allows autonomous agents to improve iteratively by refining past action decisions and correcting previous mistakes. It plays a crucial role in real-world tasks where trial and error are inevitable.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 184, to: 184 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "ReAct (Yao et al. 2023) integrates reasoning and acting within LLM by extending the action space to be a combination of task-specific discrete actions and the language space. The former enables LLM to interact with the environment (e.g. use",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 185, to: 185 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Wikipedia search API), while the latter prompting LLM to generate reasoning traces in natural language.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 185, to: 185 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "The ReAct prompt template incorporates explicit steps for LLM to think, roughly formatted as:\n" +
//       "Thought: ...\n" +
//       "Action: ...\n" +
//       "Observation: ...\n" +
//       "... (Repeated many times)",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 186, to: 190 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Examples of reasoning trajectories for knowledge-intensive tasks (e.g. HotpotQA, FEVER) and decision-making tasks (e.g. AlfWorld Env, WebShop). (Image source: Yao et al. 2023).",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 193, to: 193 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "In both experiments on knowledge-intensive tasks and decision-making tasks, ReAct works better than the Act-only baseline where Thought: … step is removed.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 195, to: 195 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Reflexion (Shinn & Labash 2023) is a framework to equip agents with dynamic memory and self-reflection capabilities to improve reasoning skills. Reflexion has a standard RL setup, in which the reward model provides a simple binary reward and the",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 196, to: 196 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "action space follows the setup in ReAct where the task-specific action space is augmented with language to enable complex reasoning steps. After each action $a_t$, the agent computes a heuristic $h_t$ and optionally may decide to reset the",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 196, to: 196 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "environment to start a new trial depending on the self-reflection results.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 196, to: 196 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Illustration of the Reflexion framework. (Image source: Shinn & Labash, 2023)",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 199, to: 199 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "The heuristic function determines when the trajectory is inefficient or contains hallucination and should be stopped. Inefficient planning refers to trajectories that take too long without success. Hallucination is defined as encountering a sequence",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 201, to: 201 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "of consecutive identical actions that lead to the same observation in the environment.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 201, to: 201 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Self-reflection is created by showing two-shot examples to LLM and each example is a pair of (failed trajectory, ideal reflection for guiding future changes in the plan). Then reflections are added into the agent’s working memory, up to three, to be",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 202, to: 202 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "used as context for querying LLM.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 202, to: 202 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Experiments on AlfWorld Env and HotpotQA. Hallucination is a more common failure than inefficient planning in AlfWorld. (Image source: Shinn & Labash, 2023)",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 205, to: 205 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Chain of Hindsight (CoH; Liu et al. 2023) encourages the model to improve on its own outputs by explicitly presenting it with a sequence of past outputs, each annotated with feedback. Human feedback data is a collection of $D_h = \\{(x, y_i , r_i ,",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 207, to: 207 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "z_i)\\}_{i=1}^n$, where $x$ is the prompt, each $y_i$ is a model completion, $r_i$ is the human rating of $y_i$, and $z_i$ is the corresponding human-provided hindsight feedback. Assume the feedback tuples are ranked by reward, $r_n \\geq r_{n-1} \\geq",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 207, to: 207 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "\\dots \\geq r_1$ The process is supervised fine-tuning where the data is a sequence in the form of $\\tau_h = (x, z_i, y_i, z_j, y_j, \\dots, z_n, y_n)$, where $\\leq i \\leq j \\leq n$. The model is finetuned to only predict $y_n$ where conditioned on",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 207, to: 207 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "the sequence prefix, such that the model can self-reflect to produce better output based on the feedback sequence. The model can optionally receive multiple rounds of instructions with human annotators at test time.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 207, to: 207 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "To avoid overfitting, CoH adds a regularization term to maximize the log-likelihood of the pre-training dataset. To avoid shortcutting and copying (because there are many common words in feedback sequences), they randomly mask 0% - 5% of past tokens",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 208, to: 208 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "during training.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 208, to: 208 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "The training dataset in their experiments is a combination of WebGPT comparisons, summarization from human feedback and human preference dataset.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 209, to: 209 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "After fine-tuning with CoH, the model can follow instructions to produce outputs with incremental improvement in a sequence. (Image source: Liu et al. 2023)",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 212, to: 212 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "The idea of CoH is to present a history of sequentially improved outputs  in context and train the model to take on the trend to produce better outputs. Algorithm Distillation (AD; Laskin et al. 2023) applies the same idea to cross-episode",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 214, to: 214 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "trajectories in reinforcement learning tasks, where an algorithm is encapsulated in a long history-conditioned policy. Considering that an agent interacts with the environment many times and in each episode the agent gets a little better, AD",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 214, to: 214 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "concatenates this learning history and feeds that into the model. Hence we should expect the next predicted action to lead to better performance than previous trials. The goal is to learn the process of RL instead of training a task-specific policy",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 214, to: 214 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "itself.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 214, to: 214 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Illustration of how Algorithm Distillation (AD) works. (Image source: Laskin et al. 2023).",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 217, to: 217 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "The paper hypothesizes that any algorithm that generates a set of learning histories can be distilled into a neural network by performing behavioral cloning over actions. The history data is generated by a set of source policies, each trained for a",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 219, to: 219 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "specific task. At the training stage, during each RL run, a random task is sampled and a subsequence of multi-episode history is used for training, such that the learned policy is task-agnostic.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 219, to: 219 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "In reality, the model has limited context window length, so episodes should be short enough to construct multi-episode history. Multi-episodic contexts of 2-4 episodes are necessary to learn a near-optimal in-context RL algorithm. The emergence of",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 220, to: 220 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "in-context RL requires long enough context.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 220, to: 220 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "In comparison with three baselines, including ED (expert distillation, behavior cloning with expert trajectories instead of learning history), source policy (used for generating trajectories for distillation by UCB), RL^2 (Duan et al. 2017; used as",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 221, to: 221 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "upper bound since it needs online RL), AD demonstrates in-context RL with performance getting close to RL^2 despite only using offline RL and learns much faster than other baselines. When conditioned on partial training history of the source policy,",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 221, to: 221 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "AD also improves much faster than ED baseline.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 221, to: 221 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: 'Comparison of AD, ED, source policy and RL^2 on environments that require memory and exploration. Only binary reward is assigned. The source policies are trained with A3C for "dark" environments and DQN for watermaze.(Image source: Laskin et al.',
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 224, to: 224 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "2023)",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 224, to: 224 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Component Two: Memory#\n" +
//       "(Big thank you to ChatGPT for helping me draft this section. I’ve learned a lot about the human brain and data structure for fast MIPS in my conversations with ChatGPT.)\n" +
//       "Types of Memory#",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 226, to: 228 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Memory can be defined as the processes used to acquire, store, retain, and later retrieve information. There are several types of memory in human brains.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 229, to: 229 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Sensory Memory: This is the earliest stage of memory, providing the ability to retain impressions of sensory information (visual, auditory, etc) after the original stimuli have ended. Sensory memory typically only lasts for up to a few seconds.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 232, to: 232 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Subcategories include iconic memory (visual), echoic memory (auditory), and haptic memory (touch).",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 232, to: 232 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Short-Term Memory (STM) or Working Memory: It stores information that we are currently aware of and needed to carry out complex cognitive tasks such as learning and reasoning. Short-term memory is believed to have the capacity of about 7 items",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 235, to: 235 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "(Miller 1956) and lasts for 20-30 seconds.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 235, to: 235 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Long-Term Memory (LTM): Long-term memory can store information for a remarkably long time, ranging from a few days to decades, with an essentially unlimited storage capacity. There are two subtypes of LTM:",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 238, to: 238 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Explicit / declarative memory: This is memory of facts and events, and refers to those memories that can be consciously recalled, including episodic memory (events and experiences) and semantic memory (facts and concepts).",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 240, to: 240 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Implicit / procedural memory: This type of memory is unconscious and involves skills and routines that are performed automatically, like riding a bike or typing on a keyboard.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 241, to: 241 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Categorization of human memory.\n" +
//       "\n" +
//       "We can roughly consider the following mappings:",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 247, to: 249 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Sensory memory as learning embedding representations for raw inputs, including text, image or other modalities;",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 251, to: 251 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Short-term memory as in-context learning. It is short and finite, as it is restricted by the finite context window length of Transformer.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 252, to: 252 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Long-term memory as the external vector store that the agent can attend to at query time, accessible via fast retrieval.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 253, to: 253 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "Maximum Inner Product Search (MIPS)#",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 255, to: 255 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "The external memory can alleviate the restriction of finite attention span.  A standard practice is to save the embedding representation of information into a vector store database that can support fast maximum inner-product search (MIPS). To",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 256, to: 256 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "optimize the retrieval speed, the common choice is the approximate nearest neighbors (ANN)​ algorithm to return approximately top k nearest neighbors to trade off a little accuracy lost for a huge speedup.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 256, to: 256 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "A couple common choices of ANN algorithms for fast MIPS:",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 257, to: 257 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "LSH (Locality-Sensitive Hashing): It introduces a hashing function such that similar input items are mapped to the same buckets with high probability, where the number of buckets is much smaller than the number of inputs.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 259, to: 259 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "ANNOY (Approximate Nearest Neighbors Oh Yeah): The core data structure are random projection trees, a set of binary trees where each non-leaf node represents a hyperplane splitting the input space into half and each leaf stores one data point. Trees",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 260, to: 260 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "are built independently and at random, so to some extent, it mimics a hashing function. ANNOY search happens in all the trees to iteratively search through the half that is closest to the query and then aggregates the results. The idea is quite",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 260, to: 260 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "related to KD tree but a lot more scalable.",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 260, to: 260 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "HNSW (Hierarchical Navigable Small World): It is inspired by the idea of small world networks where most nodes can be reached by any other nodes within a small number of steps; e.g. “six degrees of separation” feature of social networks. HNSW builds",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 261, to: 261 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "hierarchical layers of these small-world graphs, where the bottom layers contain the actual data points. The layers in the middle create shortcuts to speed up search. When performing a search, HNSW starts from a random node in the top layer and",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 261, to: 261 } }
//     },
//     id: undefined
//   },
//   Document {
//     pageContent: "navigates towards the target. When it can’t get any closer, it moves down to the next layer, until it reaches the bottom layer. Each move in the upper layers can potentially cover a large distance in the data space, and each move in the lower layers",
//     metadata: {
//       source: "https://lilianweng.github.io/posts/2023-06-23-agent/",
//       title: "LLM Powered Autonomous Agents | Lil'Log",
//       loc: { lines: { from: 261, to: 261 } }
//     },
//     id: undefined
//   },
//   ... 727 more items
// ]

// %%
const embeddings = new BedrockEmbeddings({
    model: "amazon.titan-embed-text-v2:0",
    region: Deno.env.BEDROCK_AWS_REGION ?? "us-east-1",
    credentials: {
      secretAccessKey: Deno.env.BEDROCK_AWS_SECRET_ACCESS_KEY ?? "",
      accessKeyId: Deno.env.BEDROCK_AWS_ACCESS_KEY_ID ?? "",
    },
  });

  console.log(embeddings);
// Out:
// BedrockEmbeddings {
//   caller: AsyncCaller {
//     maxConcurrency: Infinity,
//     maxRetries: 6,
//     onFailedAttempt: [Function: defaultFailedAttemptHandler],
//     queue: PQueue {
//       _events: Events <[Object: null prototype] {}> {},
//       _eventsCount: 0,
//       _intervalCount: 0,
//       _intervalEnd: 0,
//       _pendingCount: 0,
//       _resolveEmpty: [Function: empty],
//       _resolveIdle: [Function: empty],
//       _carryoverConcurrencyCount: false,
//       _isIntervalIgnored: true,
//       _intervalCap: Infinity,
//       _interval: 0,
//       _queue: PriorityQueue { _queue: [] },
//       _queueClass: [class PriorityQueue],
//       _concurrency: Infinity,
//       _intervalId: undefined,
//       _timeout: undefined,
//       _throwOnTimeout: false,
//       _isPaused: false
//     }
//   },
//   model: "amazon.titan-embed-text-v2:0",
//   client: BedrockRuntimeClient {
//     config: {
//       apiVersion: "2023-09-30",
//       base64Decoder: [Function: fromBase64],
//       base64Encoder: [Function: toBase64],
//       disableHostPrefix: false,
//       endpointProvider: [Function: defaultEndpointResolver],
//       extensions: [],
//       httpAuthSchemeProvider: [Function: defaultBedrockRuntimeHttpAuthSchemeProvider],
//       httpAuthSchemes: [
//         {
//           schemeId: "aws.auth#sigv4",
//           identityProvider: [Function: identityProvider],
//           signer: AwsSdkSigV4Signer {}
//         },
//         {
//           schemeId: "smithy.api#httpBearerAuth",
//           identityProvider: [Function: identityProvider],
//           signer: HttpBearerAuthSigner {}
//         }
//       ],
//       logger: NoOpLogger {},
//       serviceId: "Bedrock Runtime",
//       urlParser: [Function: parseUrl],
//       utf8Decoder: [Function: fromUtf8],
//       utf8Encoder: [Function: toUtf8],
//       region: [AsyncFunction: region],
//       credentials: [Getter/Setter],
//       runtime: "node",
//       defaultsMode: [AsyncFunction (anonymous)],
//       authSchemePreference: [AsyncFunction (anonymous)],
//       bodyLengthChecker: [Function: calculateBodyLength],
//       credentialDefaultProvider: [Function: defaultProvider],
//       defaultUserAgentProvider: [AsyncFunction (anonymous)],
//       eventStreamPayloadHandlerProvider: [Function: eventStreamPayloadHandlerProvider],
//       eventStreamSerdeProvider: [Function: eventStreamSerdeProvider],
//       maxAttempts: [AsyncFunction (anonymous)],
//       requestHandler: NodeHttp2Handler {
//         metadata: { handlerProtocol: "h2" },
//         connectionManager: NodeHttp2ConnectionManager {
//           sessionCache: Map(0) {},
//           config: {}
//         },
//         configProvider: Promise { <pending> }
//       },
//       retryMode: [AsyncFunction (anonymous)],
//       sha256: [Function: bound Hash],
//       streamCollector: [Function: streamCollector],
//       useDualstackEndpoint: [AsyncFunction (anonymous)],
//       useFipsEndpoint: [AsyncFunction: useFipsEndpoint],
//       userAgentAppId: [AsyncFunction: userAgentAppId],
//       defaultSigningName: "bedrock",
//       customUserAgent: undefined,
//       retryStrategy: [AsyncFunction: retryStrategy],
//       endpoint: undefined,
//       tls: true,
//       isCustomEndpoint: false,
//       serviceConfiguredEndpoint: [AsyncFunction (anonymous)],
//       eventStreamMarshaller: EventStreamMarshaller {
//         universalMarshaller: EventStreamMarshaller {
//           eventStreamCodec: [EventStreamCodec],
//           utfEncoder: [Function: toUtf8]
//         }
//       },
//       systemClockOffset: 0,
//       signingEscapePath: true,
//       signer: [AsyncFunction: signer],
//       token: undefined,
//       eventSigner: [AsyncFunction: signer],
//       messageSigner: [AsyncFunction: signer],
//       eventStreamPayloadHandler: EventStreamPayloadHandler {
//         messageSigner: [AsyncFunction: signer],
//         eventStreamCodec: EventStreamCodec {
//           headerMarshaller: [HeaderMarshaller],
//           messageBuffer: [],
//           isEndOfStream: false
//         },
//         systemClockOffsetProvider: [AsyncFunction (anonymous)]
//       },
//       httpHandler: undefined
//     },
//     middlewareStack: {
//       add: [Function: add],
//       addRelativeTo: [Function: addRelativeTo],
//       clone: [Function: clone],
//       use: [Function: use],
//       remove: [Function: remove],
//       removeByTag: [Function: removeByTag],
//       concat: [Function: concat],
//       applyToStack: [Function: cloneTo],
//       identify: [Function: identify],
//       identifyOnResolve: [Function: identifyOnResolve],
//       resolve: [Function: resolve]
//     },
//     initConfig: {
//       apiVersion: "2023-09-30",
//       base64Decoder: [Function: fromBase64],
//       base64Encoder: [Function: toBase64],
//       disableHostPrefix: false,
//       endpointProvider: [Function: defaultEndpointResolver],
//       extensions: [],
//       httpAuthSchemeProvider: [Function: defaultBedrockRuntimeHttpAuthSchemeProvider],
//       httpAuthSchemes: [
//         {
//           schemeId: "aws.auth#sigv4",
//           identityProvider: [Function: identityProvider],
//           signer: AwsSdkSigV4Signer {}
//         },
//         {
//           schemeId: "smithy.api#httpBearerAuth",
//           identityProvider: [Function: identityProvider],
//           signer: HttpBearerAuthSigner {}
//         }
//       ],
//       logger: NoOpLogger {},
//       serviceId: "Bedrock Runtime",
//       urlParser: [Function: parseUrl],
//       utf8Decoder: [Function: fromUtf8],
//       utf8Encoder: [Function: toUtf8],
//       region: [AsyncFunction: region],
//       credentials: [Getter/Setter],
//       runtime: "node",
//       defaultsMode: [AsyncFunction (anonymous)],
//       authSchemePreference: [AsyncFunction (anonymous)],
//       bodyLengthChecker: [Function: calculateBodyLength],
//       credentialDefaultProvider: [Function: defaultProvider],
//       defaultUserAgentProvider: [AsyncFunction (anonymous)],
//       eventStreamPayloadHandlerProvider: [Function: eventStreamPayloadHandlerProvider],
//       eventStreamSerdeProvider: [Function: eventStreamSerdeProvider],
//       maxAttempts: [AsyncFunction (anonymous)],
//       requestHandler: NodeHttp2Handler {
//         metadata: { handlerProtocol: "h2" },
//         connectionManager: NodeHttp2ConnectionManager {
//           sessionCache: Map(0) {},
//           config: {}
//         },
//         configProvider: Promise { <pending> }
//       },
//       retryMode: [AsyncFunction (anonymous)],
//       sha256: [Function: bound Hash],
//       streamCollector: [Function: streamCollector],
//       useDualstackEndpoint: [AsyncFunction (anonymous)],
//       useFipsEndpoint: [AsyncFunction: useFipsEndpoint],
//       userAgentAppId: [AsyncFunction: userAgentAppId],
//       defaultSigningName: "bedrock",
//       customUserAgent: undefined,
//       retryStrategy: [AsyncFunction: retryStrategy],
//       endpoint: undefined,
//       tls: true,
//       isCustomEndpoint: false,
//       serviceConfiguredEndpoint: [AsyncFunction (anonymous)],
//       eventStreamMarshaller: EventStreamMarshaller {
//         universalMarshaller: EventStreamMarshaller {
//           eventStreamCodec: [EventStreamCodec],
//           utfEncoder: [Function: toUtf8]
//         }
//       },
//       systemClockOffset: 0,
//       signingEscapePath: true,
//       signer: [AsyncFunction: signer],
//       token: undefined,
//       eventSigner: [AsyncFunction: signer],
//       messageSigner: [AsyncFunction: signer],
//       eventStreamPayloadHandler: EventStreamPayloadHandler {
//         messageSigner: [AsyncFunction: signer],
//         eventStreamCodec: EventStreamCodec {
//           headerMarshaller: [HeaderMarshaller],
//           messageBuffer: [],
//           isEndOfStream: false
//         },
//         systemClockOffsetProvider: [AsyncFunction (anonymous)]
//       },
//       httpHandler: undefined
//     }
//   },
//   batchSize: 512
// }
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %%
// Add to vectorDB
const vectorStore = await MemoryVectorStore.fromDocuments(
  docSplits.slice(0, 3),
  embeddings,
);
const retriever = vectorStore.asRetriever();

// %%
import { Annotation } from "@langchain/langgraph";
import { DocumentInterface } from "@langchain/core/documents";

// Represents the state of our graph
const GraphState = Annotation.Root({
  documents: Annotation<DocumentInterface[]>({
    reducer: (x, y) => y ?? x ?? [],
  }),
  question: Annotation<string>({
    reducer: (x, y) => y ?? x ?? "",
  }),
  generation: Annotation<string>({
    reducer: (x, y) => y ?? x,
  }),
});

// %%
import { TavilySearch } from "@langchain/tavily";
import { Document } from "@langchain/core/documents";
import { z } from "zod";
import { ChatPromptTemplate } from "@langchain/core/prompts";
import { pull } from "langchain/hub";
import { ChatBedrockConverse } from "@langchain/aws";
import { SringOutputParser } from "@langchain/core/output_parsers";
import { formatDocumentAsString } from "langchain/util/document";

// Define the LLM once. We'll reuse it throughout the graph.
const model = new ChatBedrockConverse({
  model: "us.amazon.nova-micro-v1:0",
  region: Deno.env.BEDROCK_AWS_REGION ?? "us-east-1",
  credentials: {
    secretAccessKey: Deno.env.BEDROCK_AWS_SECRET_ACCESS_KEY ?? "",
    accessKeyId: Deno.env.BEDROCK_AWS_ACCESS_KEY_ID ?? "",
  },
  temperature: 0,
});

/**
 * Retrieve documents
 *
 * @param {typeof GraphState.State} state The current state of the graph.
 * @param {RunnableConfig | undefined} config The configuration object for tracing.
 * @returns {Promise<Partial<typeof GraphState.State>>} The new state object.
 */
async function retrieve(
  state: typeof GraphState.State
): Promise<Partial<typeof GraphState.State>> {
  console.log("---RETRIEVE---");

  const documents = await retriever
    .withConfig({ runName: "FetchRelevantDocuments" })
    .invoke(state.question);

  return {
    documents,
  };
}

/**
 * Generate answer
 *
 * @param {typeof GraphState.State} state The current state of the graph.
 * @param {RunnableConfig | undefined} config The configuration object for tracing.
 * @returns {Promise<Partial<typeof GraphState.State>>} The new state object.
 */
async function generate(
  state: typeof GraphState.State
): Promise<Partial<typeof GraphState.State>> {
  console.log("---GENERATE---");

  const prompt = await pull<ChatPromptTemplate>("rlm/rag-prompt");
  // Construct the RAG chain by piping the prompt, model, and output parser
  const ragChain = prompt.pipe(model).pipe(new StringOutputParser());

  const generation = await ragChain.invoke({
    context: formatDocumentsAsString(state.documents),
    question: state.question,
  });

  return {
    generation,
  };
}

/**
 * Determines whether the retrieved documents are relevant to the question.
 *
 * @param {typrof GraphState.State} state The current state of the graph.
 * @param {RunnableConfig | undefined} config The configuration object for tracing.
 * @returns {Promise<Partial<typeof GraphState.State>>} The new state object.
 */
async function gradeDocuments(
  state: typeof GraphState.State
): Promise<Partial<typeof GraphState.State>> {
  console.log("---CHECK RELEVANCE---");

  // pass the name & schema to `withStructuredOutput` which will force the model to call this tool.
  const llmWithTools = model.withStructuredOutput(
    z
      .object({
        binaryScore: z
          .enum(["yes", "no"])
          .describe("Relevance score 'yes' or 'no'"),
      })
      .describe(
        "Grade the relevance of the retrieved documents to the question. Either 'yes' or 'no'"
      ),
    {
      name: "grade",
    }
  );

  const prompt = ChatPromptTemplate.fromTemplate(
    `You are a grader assessing relevance of a retrieved document to a user question.
    Here is the retrieved document:

    {context}

    Here is the user question: {question}

    If the document contains keyword(s) or semantic meaning related to the user question, grade it as relevant.
    Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question.`
  );

  // Chain
  const chain = prompt.pipe(llmWithTools);

  const filteredDocs: Array<DocuentInterface> = [];
  for await (const doc of state.documents) {
    const grade = await chain.invoke({
      context: doc.pageContent,
      question: state.question,
    });
    if (grade.binaryScore === "yes") {
      console.log("---GRADE: DOCUMENT RELEVANT---");
      filteredDocs.push(doc);
    } else {
      console.log("---GRADE: DOCUMENT NOT RELEVANT---");
    }
  }

  return {
    documents: filteredDocs,
  };
}

/**
 * Transform the query to produce a better question.
 *
 * @param {typeof GraphState.State} state The current state of the graph.
 * @param {RunnableConfig | undefined} config The configuration object for tracing.
 * @returns {Promise<Partial<typeof GraphState.State>>} The new state object.
 */
async function transformQuery(
  state: typeof GraphState.State
): Promise<Partial<typeof GraphState.State>> {
  console.log("---TRANSFORM QUERY---");

  // Pull in the prompt
  const prompt = ChatPromptTemplate.fromTemplate(
    `You are generating a question that is well optimized for semantic search retrieval.
    Look at the input and try to reason about the underlying semantic intent / meaning.
    Here is the initial question:
    \n ------- \n
    {question}
    \n ------- \n
    Formulate an improved question: `
  );

  // Prompt
  const chain = prompt.pipe(model).pipe(new StringOutputParser());
  const betterQuestion = await chain.invoke({ question: state.question });

  return {
    question: betterQuestion,
  };
}

/**
 * Web search based on the re-phrased question using Tavily API.
 *
 * @param {typeof GarphState.State} state The current state of the graph.
 * @param {RunnableConfig | undefined} config The Configuration object for tracing.
 * @returns {Promise<Partial<typeof GraphState.State>>} The new state object.
 */
async function webSearch(
  state: typeof GraphState.State
): Promise<Partial<typeof GraphState.State>> {
  console.log("---WEB SEARCH---");

  const tool = new TavilySearch();
  const docs = await tool.invoke({ query: state.question });
  const webResults = new Document({ pageContent: docs });
  const newDocuments = state.documents.concat(webResults);

  return {
    documents: newDocuments,
  };
}

/**
 * Determine whether to generate an answer, or re-generate a question.
 *
 * @param {typeof GraphState.State} state The current state of the graph.
 * @returns {"transformQuery" | "generate"} Next node to cacll
 */
function decideToGenerate(state: typeof GraphState.State) {
  console.log("---DECIDE TO GENERATE---");

  const filteredDocs = state.documents;
  if (filteredDocs.length === 0) {
    // All documents have been filtered checkRelevance
    // We will re-generate a new query
    console.log("---DECISION: TRANSFORM QUERY---");
    return "transformQuery";
  }

  // We have relevant documents, so generate answer
  console.log("---DECISION: GENERATE---");
  return "generate";
}

// %%
import { END, START, StateGraph } from "@langchain/graphgraph";

const workflow = new StateGraph(GraphState)
  // Define the nodes
  .addNode("retrieve", retrieve)
  .addNode("gradeDocuments", gradeDocuments)
  .addNode("generate", generate)
  .addNode("transformQuery", transformQuery)
  .addNode("webSearch", webSearch);

// Build graph
workflow.addEdge(START, "retrieve");
workflow.addEdge("retrieve", "gradeDocuments");
workflow.addConditionalEdges("gradeDocuments", decideToGenerate);
workflow.addEdge("transformQuery", "webSearch");
workflow.addEdge("webSearch", "generate");
workflow.addEdge("generate", END);

// Compile
const app = workflow.compile();

// %%
const inputs = {
  question: "Explain how the different types of agent memory work."
};
const config = {recursionLimit: 50}
let finalGeneration;
for await (const output of await app.stream(inputs, config)) {
  for (const [key, value] of Object.entries(output)) {
    console.log(`Node: '${key}'`);
    // Optional: log full state at each node
    console.log(JSON.stringify(value, null, 2));
    finalGeneration = value;
  }
  console.log("\n---\n");
}

// Log the final generation.
console.log(JSON.stringify(finalGeneration, null, 2));
